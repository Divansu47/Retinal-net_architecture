# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/traffic-data/traffic_wala_dataset/data.yaml
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/12_mp4-10_jpg.rf.4bb699a2ec90e19cb4680ee239ae579c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/6_mp4-31_jpg.rf.c786274ab129629ca618e454b4146f11.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/6_mp4-29_jpg.rf.e73ca25e92e590b325006f010ad4e319.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/4_mp4-8_jpg.rf.1d199d41f6c3738763c192883ad1a5b4.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/7_mp4-24_jpg.rf.ed2484fe45c32f27443cccd8bbf99361.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/2_mp4-1_jpg.rf.b52c12a365fbeb71e302f0505038959b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/test2_mp4-21_jpg.rf.bbb3ba4e4b69e5a12822300829bf75f0.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/7_mp4-11_jpg.rf.02a513fa7473144494b7a53fc14b6560.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/3_mp4-2_jpg.rf.fb3ec30812baf2bbaca8718878601bde.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/11_mp4-7_jpg.rf.c29830bf45870c97e8667ce13c0994a9.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/5_mp4-5_jpg.rf.47c7656c79a6cfa7dbabfcaaeef94dea.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/test2_mp4-8_jpg.rf.c10dd559d44a868fd6f6877fd734815a.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/5_mp4-9_jpg.rf.7935a441141908423532c47b7ac06cde.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/11_mp4-29_jpg.rf.f4e8f8309727d46eec20a7c469f54d9c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/10_mp4-13_jpg.rf.aff71e875ee297d3086b715b7d6aaf26.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/13_mp4-16_jpg.rf.dbcfa7de2863879d3000ca35d30610e9.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/6_mp4-23_jpg.rf.1b0bacb47ce35aab7a6ddd69b6f7f334.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/8_mp4-45_jpg.rf.459ab8691a64f40ebf3a5ab525476aca.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/12_mp4-18_jpg.rf.3a9772dc3c051396fd79732651cb66a3.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/8_mp4-14_jpg.rf.e15e22de0316fce6d319640eae7a04c3.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/8_mp4-39_jpg.rf.bf01d183fca62e3316a0e4b31bfdf0da.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/test_mp4-2_jpg.rf.7aa04dc29802950b7aa81fd4f5cc5d7c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/12_mp4-16_jpg.rf.0fcd57e7a8e7f4345ede8d494fbc75be.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/14_mp4-10_jpg.rf.edf4723435ff483f7d55c474a60be14d.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/15_mp4-10_jpg.rf.36bd6816aa11df00d569dd41116d9322.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/14_mp4-0_jpg.rf.a9de046366e99b1b12a43c93614e1c60.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/6_mp4-1_jpg.rf.a30955a1b5b2a8db39354221db4f5b5f.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/test3_mp4-5_jpg.rf.9750bf1cd88f2dce07edd907b7dc61f4.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/5_mp4-27_jpg.rf.30a8975089fb66bc245019de9d868801.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/test_mp4-15_jpg.rf.2e20880f4bc2ad6347a6a98e8f4ef849.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/8_mp4-6_jpg.rf.9eddb296d3861c6af62c2d2c3ca30fb2.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/6_mp4-0_jpg.rf.9a055d040151678e04cb48a8bde76f55.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/16_mp4-1_jpg.rf.3493f4b7618e207609847857a20dbaff.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/_annotations.csv
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/5_mp4-29_jpg.rf.de506ae3402dafeffb1e6427af894871.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/2_mp4-5_jpg.rf.bb490ff3835ac898dedea95c973038f5.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/13_mp4-9_jpg.rf.e26b4d37b22952e51e74e45fccb725c4.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/11_mp4-15_jpg.rf.b1bdb8b4864b5bed3c78f1a70e2dc011.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/2_mp4-10_jpg.rf.97b46cb44bcae5057b47db4ebbbe9305.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/13_mp4-5_jpg.rf.8c55dff632bf3a3a35da021c5bd43091.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/4_mp4-1_jpg.rf.a1b873f83491736ca8bc5817761a2ec3.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/test2_mp4-19_jpg.rf.a3723816acc8bacb1350cc05fb78b924.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/8_mp4-22_jpg.rf.cc0d05137c80f5ef9057177e101b4e13.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/test3_mp4-4_jpg.rf.4117c2b721818a818f810d1ed547e1db.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/13_mp4-21_jpg.rf.384d3e564126403c9eeb3ad9deebf3a6.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/8_mp4-3_jpg.rf.05628975b0d5e011fe6ada765f915cd1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/10_mp4-31_jpg.rf.0daa09b648954e3a19824a49ad49876e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/7_mp4-5_jpg.rf.4fbccc6bf11dc163e1ff276014a55561.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/12_mp4-24_jpg.rf.b5c9acb867e41055973828d5c43ed57e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/8_mp4-19_jpg.rf.5a133390424449e110bab4a90be94355.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/2_mp4-22_jpg.rf.7e53e9a475efa9889dc0a74380255e9b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/14_mp4-5_jpg.rf.56b529ccef99d8c81d68610e5a5e3929.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/11_mp4-28_jpg.rf.afaa0527199e4ac7b9564b9552575d33.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/4_mp4-7_jpg.rf.439bc6176789cd7ca6bd686e23fc5ddf.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/14_mp4-15_jpg.rf.9640ab027504af3733b76827756764eb.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/8_mp4-12_jpg.rf.dcbef9dfc2cf3b8eecf139c256caa179.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/1_mp4-0_jpg.rf.71f17d5bdbcac3f9939ae34558b63288.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/6_mp4-10_jpg.rf.4e74eb10d5dc733c083cdf4f227386ab.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/2_mp4-17_jpg.rf.2948c849931a8eff6c6641d24c1cfc8f.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/10_mp4-0_jpg.rf.08b3bd34bbb73fb80c2d662c34474a98.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/14_mp4-24_jpg.rf.57d5fe50d543f58e3b1f761ee53e1aa8.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/10_mp4-9_jpg.rf.72a35ba2f76343afc7a101e720dbbb81.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/5_mp4-21_jpg.rf.e1f8c70bc4d3aee7e30f029aa44fd7a0.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/10_mp4-39_jpg.rf.af70092b5f2277f16d2703a4d59c3313.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/10_mp4-16_jpg.rf.b01cbf556a5a2c4154322deda0339880.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/10_mp4-23_jpg.rf.13b084ba8417c6d0aaf5d4c35ddba6ac.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/_annotations.coco.json
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/7_mp4-6_jpg.rf.3f9214d14313fa7dd572e7739bbe7398.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/5_mp4-26_jpg.rf.61d8ef7774c6c33aa7015c91dc91aa34.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/11_mp4-24_jpg.rf.49cf501f701c9bba3f940e2c9530d258.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/15_mp4-6_jpg.rf.f8ad77cac61af6ee1b551af09789bc24.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/test_mp4-10_jpg.rf.2ca4c14abaa5734493da3c35e2089f1c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/3_mp4-8_jpg.rf.4a784fedfdd385032614371ea5cb78fa.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/test3_mp4-8_jpg.rf.8223a2cf9be640b80ee97b8c3e46d8c3.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/test2_mp4-16_jpg.rf.585413166ce3fb74dc3e975edc009020.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/13_mp4-18_jpg.rf.4ad6c1d97b9a99efd21cbbf3f6da9d89.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/test2_mp4-1_jpg.rf.695e12d07d9427f18d33d1e69827075f.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/test_mp4-13_jpg.rf.98cd77f75c4492f8f103aaf4ce2ca8f8.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/6_mp4-24_jpg.rf.b11ebad90583e724f447a295f04e9bf0.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/11_mp4-2_jpg.rf.4297efcf4f8f508d37d3310e30dc2b96.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/3_mp4-17_jpg.rf.fdfd6a4ddf7c5f516a940b2452857d67.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/10_mp4-35_jpg.rf.5de759e599ee930d33ec127e04347f97.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/3_mp4-14_jpg.rf.6597c5732e0d554f1f07edb59abb4f8b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/8_mp4-0_jpg.rf.3b2c1cfee1946594ca79d413e945d30a.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/7_mp4-16_jpg.rf.4adf9f6fc7b5f6571fd1ef429cd79026.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/10_mp4-46_jpg.rf.6f582e01a1a77c50f2716ac606abe4fe.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/15_mp4-0_jpg.rf.f4bc7ddd112a3eca776a8cf90c3f7bb1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/6_mp4-14_jpg.rf.a5099c3eeb2c707a2193c0efa467bb2a.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/10_mp4-25_jpg.rf.11c919cc683cc6a0d0a658be13483748.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/12_mp4-27_jpg.rf.2b272befa75f6ccd269223ccc84e5391.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/12_mp4-2_jpg.rf.079207e8096200ec6c611a449898ad40.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/labels/14_mp4-2_jpg.rf.2f13b98e9712d8b5bef0b7b419a376b2.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/6_mp4-0_jpg.rf.9a055d040151678e04cb48a8bde76f55.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/12_mp4-10_jpg.rf.4bb699a2ec90e19cb4680ee239ae579c.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/13_mp4-21_jpg.rf.384d3e564126403c9eeb3ad9deebf3a6.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/14_mp4-0_jpg.rf.a9de046366e99b1b12a43c93614e1c60.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/13_mp4-5_jpg.rf.8c55dff632bf3a3a35da021c5bd43091.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/7_mp4-6_jpg.rf.3f9214d14313fa7dd572e7739bbe7398.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/7_mp4-5_jpg.rf.4fbccc6bf11dc163e1ff276014a55561.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/14_mp4-5_jpg.rf.56b529ccef99d8c81d68610e5a5e3929.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/2_mp4-17_jpg.rf.2948c849931a8eff6c6641d24c1cfc8f.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/12_mp4-24_jpg.rf.b5c9acb867e41055973828d5c43ed57e.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/4_mp4-7_jpg.rf.439bc6176789cd7ca6bd686e23fc5ddf.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/1_mp4-0_jpg.rf.71f17d5bdbcac3f9939ae34558b63288.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/8_mp4-19_jpg.rf.5a133390424449e110bab4a90be94355.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/12_mp4-18_jpg.rf.3a9772dc3c051396fd79732651cb66a3.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/6_mp4-24_jpg.rf.b11ebad90583e724f447a295f04e9bf0.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/14_mp4-2_jpg.rf.2f13b98e9712d8b5bef0b7b419a376b2.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/6_mp4-1_jpg.rf.a30955a1b5b2a8db39354221db4f5b5f.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/test2_mp4-21_jpg.rf.bbb3ba4e4b69e5a12822300829bf75f0.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/11_mp4-24_jpg.rf.49cf501f701c9bba3f940e2c9530d258.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/2_mp4-5_jpg.rf.bb490ff3835ac898dedea95c973038f5.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/6_mp4-14_jpg.rf.a5099c3eeb2c707a2193c0efa467bb2a.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/10_mp4-39_jpg.rf.af70092b5f2277f16d2703a4d59c3313.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/8_mp4-39_jpg.rf.bf01d183fca62e3316a0e4b31bfdf0da.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/3_mp4-14_jpg.rf.6597c5732e0d554f1f07edb59abb4f8b.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/test2_mp4-8_jpg.rf.c10dd559d44a868fd6f6877fd734815a.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/12_mp4-27_jpg.rf.2b272befa75f6ccd269223ccc84e5391.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/3_mp4-2_jpg.rf.fb3ec30812baf2bbaca8718878601bde.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/test2_mp4-16_jpg.rf.585413166ce3fb74dc3e975edc009020.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/test3_mp4-5_jpg.rf.9750bf1cd88f2dce07edd907b7dc61f4.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/5_mp4-29_jpg.rf.de506ae3402dafeffb1e6427af894871.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/11_mp4-15_jpg.rf.b1bdb8b4864b5bed3c78f1a70e2dc011.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/5_mp4-21_jpg.rf.e1f8c70bc4d3aee7e30f029aa44fd7a0.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/5_mp4-27_jpg.rf.30a8975089fb66bc245019de9d868801.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/10_mp4-0_jpg.rf.08b3bd34bbb73fb80c2d662c34474a98.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/8_mp4-6_jpg.rf.9eddb296d3861c6af62c2d2c3ca30fb2.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/7_mp4-11_jpg.rf.02a513fa7473144494b7a53fc14b6560.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/7_mp4-24_jpg.rf.ed2484fe45c32f27443cccd8bbf99361.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/4_mp4-8_jpg.rf.1d199d41f6c3738763c192883ad1a5b4.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/8_mp4-14_jpg.rf.e15e22de0316fce6d319640eae7a04c3.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/10_mp4-46_jpg.rf.6f582e01a1a77c50f2716ac606abe4fe.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/2_mp4-10_jpg.rf.97b46cb44bcae5057b47db4ebbbe9305.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/test3_mp4-8_jpg.rf.8223a2cf9be640b80ee97b8c3e46d8c3.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/6_mp4-31_jpg.rf.c786274ab129629ca618e454b4146f11.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/11_mp4-28_jpg.rf.afaa0527199e4ac7b9564b9552575d33.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/11_mp4-7_jpg.rf.c29830bf45870c97e8667ce13c0994a9.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/11_mp4-2_jpg.rf.4297efcf4f8f508d37d3310e30dc2b96.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/15_mp4-10_jpg.rf.36bd6816aa11df00d569dd41116d9322.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/test_mp4-2_jpg.rf.7aa04dc29802950b7aa81fd4f5cc5d7c.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/6_mp4-10_jpg.rf.4e74eb10d5dc733c083cdf4f227386ab.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/10_mp4-35_jpg.rf.5de759e599ee930d33ec127e04347f97.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/10_mp4-23_jpg.rf.13b084ba8417c6d0aaf5d4c35ddba6ac.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/10_mp4-13_jpg.rf.aff71e875ee297d3086b715b7d6aaf26.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/7_mp4-16_jpg.rf.4adf9f6fc7b5f6571fd1ef429cd79026.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/16_mp4-1_jpg.rf.3493f4b7618e207609847857a20dbaff.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/10_mp4-16_jpg.rf.b01cbf556a5a2c4154322deda0339880.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/12_mp4-16_jpg.rf.0fcd57e7a8e7f4345ede8d494fbc75be.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/15_mp4-6_jpg.rf.f8ad77cac61af6ee1b551af09789bc24.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/8_mp4-45_jpg.rf.459ab8691a64f40ebf3a5ab525476aca.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/5_mp4-9_jpg.rf.7935a441141908423532c47b7ac06cde.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/5_mp4-26_jpg.rf.61d8ef7774c6c33aa7015c91dc91aa34.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/2_mp4-22_jpg.rf.7e53e9a475efa9889dc0a74380255e9b.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/test2_mp4-19_jpg.rf.a3723816acc8bacb1350cc05fb78b924.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/test_mp4-13_jpg.rf.98cd77f75c4492f8f103aaf4ce2ca8f8.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/15_mp4-0_jpg.rf.f4bc7ddd112a3eca776a8cf90c3f7bb1.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/3_mp4-8_jpg.rf.4a784fedfdd385032614371ea5cb78fa.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/6_mp4-29_jpg.rf.e73ca25e92e590b325006f010ad4e319.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/5_mp4-5_jpg.rf.47c7656c79a6cfa7dbabfcaaeef94dea.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/10_mp4-9_jpg.rf.72a35ba2f76343afc7a101e720dbbb81.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/8_mp4-12_jpg.rf.dcbef9dfc2cf3b8eecf139c256caa179.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/test2_mp4-1_jpg.rf.695e12d07d9427f18d33d1e69827075f.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/test_mp4-15_jpg.rf.2e20880f4bc2ad6347a6a98e8f4ef849.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/8_mp4-0_jpg.rf.3b2c1cfee1946594ca79d413e945d30a.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/3_mp4-17_jpg.rf.fdfd6a4ddf7c5f516a940b2452857d67.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/6_mp4-23_jpg.rf.1b0bacb47ce35aab7a6ddd69b6f7f334.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/8_mp4-3_jpg.rf.05628975b0d5e011fe6ada765f915cd1.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/14_mp4-10_jpg.rf.edf4723435ff483f7d55c474a60be14d.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/2_mp4-1_jpg.rf.b52c12a365fbeb71e302f0505038959b.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/14_mp4-15_jpg.rf.9640ab027504af3733b76827756764eb.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/13_mp4-18_jpg.rf.4ad6c1d97b9a99efd21cbbf3f6da9d89.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/14_mp4-24_jpg.rf.57d5fe50d543f58e3b1f761ee53e1aa8.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/13_mp4-16_jpg.rf.dbcfa7de2863879d3000ca35d30610e9.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/test_mp4-10_jpg.rf.2ca4c14abaa5734493da3c35e2089f1c.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/11_mp4-29_jpg.rf.f4e8f8309727d46eec20a7c469f54d9c.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/4_mp4-1_jpg.rf.a1b873f83491736ca8bc5817761a2ec3.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/test3_mp4-4_jpg.rf.4117c2b721818a818f810d1ed547e1db.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/10_mp4-31_jpg.rf.0daa09b648954e3a19824a49ad49876e.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/12_mp4-2_jpg.rf.079207e8096200ec6c611a449898ad40.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/13_mp4-9_jpg.rf.e26b4d37b22952e51e74e45fccb725c4.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/8_mp4-22_jpg.rf.cc0d05137c80f5ef9057177e101b4e13.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/valid/images/10_mp4-25_jpg.rf.11c919cc683cc6a0d0a658be13483748.jpg
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-0_jpg.rf.13768a6bc89343d1f3a551945edea8ed.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-7_jpg.rf.8624d28bb3c29c80ec9283fdab5f19e8.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-10_jpg.rf.4700be742c709d3ebbac02e5f323cd12.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-8_jpg.rf.25c000e17a6f603a228386f9780e87a1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-41_jpg.rf.4dee909f4a5f9be3f96de326a0d087e0.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-14_jpg.rf.00ee0a5c6158d66128aded7ba6c5e3c2.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-4_jpg.rf.a20b7a6e45f87da6fb6a63f76ec8130d.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test_mp4-4_jpg.rf.c92ba4917bf77f870bd07eeac79fdfb1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/15_mp4-8_jpg.rf.c12aa7b103f55effa7a163a438e2e007.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-28_jpg.rf.725015477afc0e20fa01fee42ed7f6d9.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/13_mp4-6_jpg.rf.684f923a639ff5c8659bf85ad06ffc0e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-17_jpg.rf.2e3ed9c1f0377b9c96f90eca8f4bdb89.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-3_jpg.rf.effcef40b551938436308ac1eef276bc.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-2_jpg.rf.93839f8a7f08d9dbdc08e77656f9ab9d.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/4_mp4-9_jpg.rf.e3a0948ae1c9e253e1926ed1a7f921e7.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/13_mp4-13_jpg.rf.8a0240ede51d6ffd963d0cf7cf26eb3a.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-20_jpg.rf.6c674e43bf5be6b4071c65291ac2b13c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-20_jpg.rf.5f56c19d629aec9af8972f03b80764b4.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-8_jpg.rf.8912d23559a90d712ef2cacace5a3370.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-12_jpg.rf.e120108ef5fe771c4687aac68f87d470.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/3_mp4-3_jpg.rf.4cd6ebd1fb8dd1a97e3320f0d63d02bb.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/1_mp4-8_jpg.rf.2641280818f70f41aff18978dc2b189e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/13_mp4-0_jpg.rf.620b394144dc86057a91d894c3d9fc3f.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test3_mp4-15_jpg.rf.1fac3e2c2d15c1be7beeac54f1257278.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-42_jpg.rf.f9b68b0eda6ceec8b0447dfbe184600d.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-9_jpg.rf.6ef67b89a1db64a28d72b3fc76166f18.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-32_jpg.rf.76db89bfdfeb0e355e9ad3c05ee8ac8e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test_mp4-11_jpg.rf.264e26445af0bb22012f9f6ed5b4026b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-7_jpg.rf.ecf31a5f0a3ade904c24d0fef1a18506.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test3_mp4-9_jpg.rf.ad91cc5f0adc2a68f4e733329c9d06ea.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/13_mp4-2_jpg.rf.91937da497cdf5495ee3fd2d4b8ab29c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/4_mp4-5_jpg.rf.2b8ca422636e50569ca285a2cc484759.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-32_jpg.rf.2fbf5f14e51e9a234d170de78381cfbb.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-40_jpg.rf.c87ea31b3ee340155d9d5a389565aa13.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-7_jpg.rf.fab6475c4142d7bce5b9b4951adc03dc.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-33_jpg.rf.beb62cf3f5093f147e9156aa8144c8a0.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-4_jpg.rf.a9d56eba757aa96a9e1e7d70518133db.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-28_jpg.rf.9a9bcb32780aa931718551884825de05.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-4_jpg.rf.3f43e19049f651b66e3f965067ffcc72.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-1_jpg.rf.0244caebff9c38f077c73832a1b99def.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-19_jpg.rf.6ae16e974bff5573d4908ba74de6bad7.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-40_jpg.rf.d16cc80521ce7580afbf20eda5adf6d3.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-2_jpg.rf.80ba24bc2c575533fd8859a640c4e6b7.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/1_mp4-5_jpg.rf.402cab70fefdc188c812bbc47a4ed5fd.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-37_jpg.rf.5cc75f111b203c26d41614719c2ee50e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-48_jpg.rf.b136b51c70d8645bcb71e77a647c9c23.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-8_jpg.rf.a0e1a9d3a8cb937318b64d250da13d21.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-43_jpg.rf.4bcb6ffca030d883c8c959a810a21398.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-28_jpg.rf.f6db4c3a56b99c14c71e544330e1ce9c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-26_jpg.rf.43acbba3d5b062f823f545eca92636fd.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-12_jpg.rf.9e1176035b38e59879d9744521174cc9.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-4_jpg.rf.9ffe523f7e7e8e84bade81014fb428f3.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-15_jpg.rf.8004ad58a025777c63c98e28c7f97a40.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-5_jpg.rf.4658c3b313fae76b64c72163de6ffa3a.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-13_jpg.rf.a72cc7ec3a11f2749ce52f59d91bb8e2.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-29_jpg.rf.34ff90a6933dde0cddf6f6a4a92e5c8e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-0_jpg.rf.2696be0f494f104bce56016175f438dc.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-33_jpg.rf.f43198a40d00d999acb21250bb837256.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-6_jpg.rf.5baaaf56d93028a9c01bc7f1696d033e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-26_jpg.rf.9f4ddce5c1bb0ee02fd1c1f6a9220fcc.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-11_jpg.rf.730138939319fc38b0f80ebc71dfee4b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-7_jpg.rf.88df9b56e4c2322a9160241b63872bfd.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/3_mp4-6_jpg.rf.5b6942de895ed79a12ff6a65888e7f17.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-8_jpg.rf.d87434ea22954af69d2692f24484a62f.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test_mp4-16_jpg.rf.b12a186127cb94dc8bc944a0ef428251.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-13_jpg.rf.a065f14e787f2be7a3d9f2149256f7ed.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-9_jpg.rf.da40e3a3763ab632f2546a683a2cf63a.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/7_mp4-8_jpg.rf.756a6c6425b6de09a0ef29517c7b6c1f.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-36_jpg.rf.28a8e51eebbdaefee515582821f1c033.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-28_jpg.rf.e5c6953d26633f73c485d2c5a389a565.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-29_jpg.rf.11ac820cd8ab2ff5beac952edd73282b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/15_mp4-12_jpg.rf.5bb8ac4e9d13f6e2e0ccd39318f4a2f2.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-23_jpg.rf.2d867a2c21f60ad6738206710c8edf1b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-12_jpg.rf.e719ef93a518a13b4653899c443a0479.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-28_jpg.rf.4344efaadc635c8dd42d8f9186f1ad71.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/13_mp4-7_jpg.rf.dd0f0e260a201d7e60b1df8705877838.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-6_jpg.rf.7854ea55c88c26a6a3b349e31fcb9964.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-16_jpg.rf.4b04bbdd5fae04f213e3c91e9c4b1b7d.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-38_jpg.rf.55f0590d14f6c99d48c77d167c621314.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/1_mp4-3_jpg.rf.f92d5d0c2629b03306c8fa91917f3ebf.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-12_jpg.rf.dfcc35ec0d85720ffdc2d3fa5ccbc6f1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-8_jpg.rf.239f33195af4df09618f08d958997ef1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/1_mp4-5_jpg.rf.11d181be65dc49ad1857dd37a817816b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-25_jpg.rf.2a6c6c461210b5066240288447ce7606.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-18_jpg.rf.232eb0c62531b8d80bc603479037dd19.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-23_jpg.rf.d6c70bd918c7036dc4822fed74817bad.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-0_jpg.rf.47b087257df01a5096eb2ac85f06b278.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-44_jpg.rf.57a54adb829943b4a4e208c0b2176b53.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/13_mp4-1_jpg.rf.e32506b2b1227a71abf30d5669e62a9a.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-2_jpg.rf.82a65b2ef22f38a52ab4a45b6734bd7f.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-14_jpg.rf.9b21d06644b165842c77f0c5ace1af8c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-35_jpg.rf.48307485007b75d42c317ef120f39758.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-2_jpg.rf.bce7192fe62613a748e7041b93e703bf.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-25_jpg.rf.17b87829fcab7614f59da979438029f5.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test3_mp4-12_jpg.rf.4d7c26225449831445c08fc842caeb48.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-26_jpg.rf.4a510cf9628a48a134aba5889a56a228.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-5_jpg.rf.598eb70537e759bb3ff0127826bad1c1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-8_jpg.rf.6a5cd35540382c3fbe00632805ba7a18.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-21_jpg.rf.fdf9ca13094603f25c5323c71537b39c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/7_mp4-13_jpg.rf.a448a1afa3608c0c65f76fbbc6f21389.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/7_mp4-1_jpg.rf.0aca74d617d7e49e8ce1b361f55bd39a.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-10_jpg.rf.b87509668caff369c5501325477e6d9a.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-21_jpg.rf.9d2986bb8a605563c3006bae400e21ff.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-21_jpg.rf.e775b93681848cb2a2a0f2e0101ea67c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/13_mp4-14_jpg.rf.347d62482862a92cbfa009ce06e6ca82.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/4_mp4-3_jpg.rf.24133af9a76ae8e25d2271059cd57edd.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test3_mp4-7_jpg.rf.4770e23f8843725328596c4ae7e2ee40.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-3_jpg.rf.2b5cba201b56df739b95e501427ac5f1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/4_mp4-6_jpg.rf.a1790a3342455a63f510d31ed789421d.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-14_jpg.rf.0d47483007a70d056747d619748e0e0a.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-22_jpg.rf.ad54dce64386ae27a580eaba4148fde4.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/1_mp4-11_jpg.rf.a41edc350c5d4dbdd6c00f77c9245233.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/13_mp4-8_jpg.rf.4b59181b0d71d00ba84f2925c6ed2413.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-31_jpg.rf.28c8daf49c5008a60e512341cfb79352.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-27_jpg.rf.8bf4487b15fa86e85a5bfe527fbca8de.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-18_jpg.rf.5a293877d4a4d20a8bfa9cdf7e062acd.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/15_mp4-11_jpg.rf.d9560da9663dba2cc2e1c6cc0937ddab.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/3_mp4-6_jpg.rf.b9cdd6989470f53d1e5e229abfaa82e1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test3_mp4-3_jpg.rf.91ab3bd359dbc8cfe7331b899161be52.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-9_jpg.rf.96d62616cba7f1351137c379b83bbc6c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-17_jpg.rf.11aa87d1f1b9f3d2b7e97091cf100588.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-11_jpg.rf.b6939bdda9abe332ee65b4672626d24b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-22_jpg.rf.9fab549aabb1a27af45313dcf1110285.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-38_jpg.rf.d9fa042ed2767de9a03b10c90794a33b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-16_jpg.rf.96743b16582cfefbb336e23cfc0ad137.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-47_jpg.rf.c9acbc3f5131327b281f3c4efd496455.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-17_jpg.rf.d95b42ea41270dad58df2fac3234fc4a.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-3_jpg.rf.ceca85e307966190ef2dc0444b462490.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/3_mp4-15_jpg.rf.ec6dc259617ea230e7f887b2bf13f067.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-27_jpg.rf.b1a5c9056348ce08ccb6bdadde8911a9.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-20_jpg.rf.fddf8750c1c1eaa6e43377e6e5028576.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-18_jpg.rf.a7d2bb35b6d0131ff01083f64244f27c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-16_jpg.rf.35a8d10e978328cd1ab87e911169b0f9.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-23_jpg.rf.ccaf85702e19a073ba49b4814d15e282.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/15_mp4-1_jpg.rf.d9e25b0686dad85b97ebd560d917fb67.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-35_jpg.rf.438a197399d1df7f8ab56f81ff845475.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/7_mp4-12_jpg.rf.28303fed2256dac5798dbf0f4f23145a.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-34_jpg.rf.24149d8b7f6202bae6717110780e5c95.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-33_jpg.rf.e6259974f6ff91def84d687db31b44d9.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-3_jpg.rf.1f86559aebcf2d5c702f5b12c02f121c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-3_jpg.rf.9df05747484088464191b55d5ff379f4.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test3_mp4-1_jpg.rf.016315de09e8befd7cb08f04805bbe98.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/7_mp4-18_jpg.rf.375c66297d68d427418697d3778553fa.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-26_jpg.rf.fae0f0e4cbc5c3563680182e8dae8483.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/3_mp4-23_jpg.rf.1795ebf65f44c643262e9abc56d89104.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-24_jpg.rf.5da4f014b207261b073ddf18806f58d6.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-6_jpg.rf.1ccc4d77ec0dabdcecdce2ed942c886b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-25_jpg.rf.ef41c1bc4522e38ce1816e5884b1761c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test3_mp4-2_jpg.rf.0eb8b9c1b003d3e856e0e3d959904d0d.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/13_mp4-19_jpg.rf.545677168812e2d50c6902861373205c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-2_jpg.rf.98ade04a432ddb5023dbcac0ae2a155c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-45_jpg.rf.5aaed7f7db29ad6c15a4b18a7ecc0b7e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-18_jpg.rf.a95aa1242272f730fde1eff19f24fbc0.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/3_mp4-7_jpg.rf.6a4f5863e2cbb994ec424cf728a19a6d.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-38_jpg.rf.76cdb330ed3dde7d0327c472dc71703f.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/1_mp4-6_jpg.rf.23b382bca47939ebcf23f544c0f33e42.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-20_jpg.rf.75c4d223b3e358d3a586fc0247467647.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test_mp4-6_jpg.rf.ab38a9d333977a3fcab122470c9e0f1e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-5_jpg.rf.6f4501c66d7db589329e2b0640a38263.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-26_jpg.rf.eded278a2f01b39511564084ee73fa19.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-34_jpg.rf.aa50d3efc81bf097dea5f5253c154aaf.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test_mp4-0_jpg.rf.232bf375741c2f099f7c5574920f52e1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-5_jpg.rf.0f649cf86a28d3c1bf566457bd741fd2.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-7_jpg.rf.e6fd259878736bb130789076b260d0c5.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-9_jpg.rf.a577fbe347e44a73a27f71bef2280343.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/7_mp4-10_jpg.rf.5a004a3e81fecf70932025e0a55e4c97.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-3_jpg.rf.5531b7d160afcc77a61e2a2ca57a73d2.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/15_mp4-4_jpg.rf.42ed2a92f886524020cf13233fab7d2b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-21_jpg.rf.f4a71342a87fe4b057dfdfd961ea7f56.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test3_mp4-0_jpg.rf.dc0ac3591666d7ed5e8fefa5b41836ff.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-39_jpg.rf.9d02f67923967da4bd61d641a7b73bc8.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-12_jpg.rf.61c94dbcac908e69c10575351f04fda4.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-18_jpg.rf.a100a7aa041746e8df5dbfa2898a2e57.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-18_jpg.rf.4319bfbb7bc9b9f40a62a13cacc1e71c.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-17_jpg.rf.02e3d8a618f9ac724fa0c2f286c728b2.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-15_jpg.rf.02b161cef4b0b0f8c2e0d76a0298c959.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-23_jpg.rf.3323026776a47d27e926c90a938ada33.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/7_mp4-7_jpg.rf.56e4e81d0c272cf24f32de07ea200ae1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-8_jpg.rf.4c673a07eb2036f47402d162d559c7d1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-30_jpg.rf.73eafea5e7f73f941543d3dcbe68afe4.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/1_mp4-6_jpg.rf.b1942799e938382319ad0a67b09f5737.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-34_jpg.rf.5628b69630116859633feaa1b4062547.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/3_mp4-0_jpg.rf.486762d73755e270c07dd8cfbeb78c05.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-23_jpg.rf.9630295f3c98ec2ad851a859992d2527.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-8_jpg.rf.76097ce0ac4ef6c0a569cae4a890a860.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-30_jpg.rf.b58c644f3265885bafe83b36369026eb.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-18_jpg.rf.de728b4158742cd5145f798bb8f28f1f.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-1_jpg.rf.95d7900831e7287cafe8f30b7ff9dcb6.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/1_mp4-10_jpg.rf.efbf093676a1b487d1e89066689cb42b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test_mp4-5_jpg.rf.26235610c8dea9da5c268fdccab4708d.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-7_jpg.rf.3772fccf9706393c58387ed585727446.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/13_mp4-3_jpg.rf.e2c753716f39f02eb40f213a7b15a6c7.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-30_jpg.rf.b925fd8ed9bd23c8011292c6eda3e69b.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-15_jpg.rf.dfb0a15fa6d3cd31bc959c8108103644.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-7_jpg.rf.284c9be103a7a8ce600e4b551456f733.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-14_jpg.rf.a6c45353302e18201614a5b3f5a375a9.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/1_mp4-7_jpg.rf.ac2a271a5a65215847db83795e848aeb.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/1_mp4-1_jpg.rf.9115af93de4cbf89e48a9c33dfe996c8.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-25_jpg.rf.e8c0b76723f677598e6863520ec02e2e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-1_jpg.rf.de00bc564859a4ccd6d2949c6db07dec.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-8_jpg.rf.71c95cfe2fd0833c1d883674c9f64dc0.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test3_mp4-2_jpg.rf.427a25cd37cd34579b0549254b76f8ed.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-7_jpg.rf.16ac55ef0554d1232db8749f7ed0f8be.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-25_jpg.rf.7d566fdc0a2fc6724202d8749dc7e42f.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-3_jpg.rf.5a7c2c046737a3469d5e74a2c7e06d6e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-8_jpg.rf.7d2094c86c3594bbf5da59e3777ee929.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/7_mp4-0_jpg.rf.caff8c9896c6f6985f2dd82b83657e4e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-27_jpg.rf.b50ed53071de55bd4882d8401cd4764d.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test_mp4-17_jpg.rf.8eccce93a3d7b586f8a75e1f4d7f5727.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-36_jpg.rf.4ecae1c1db8d348de07e4f6e9aeff577.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-15_jpg.rf.908f4888d0fa2c7bde31ba6d17768cf8.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-13_jpg.rf.a107982b284a27b0e03cf09e254f89d2.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-9_jpg.rf.efc7c8ae5059cc27b41a1f38decc1991.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/12_mp4-22_jpg.rf.3cc9c3957581c0df541bcf44be601d7e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-10_jpg.rf.654cb269de522379187cee9e5c17a8b4.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-2_jpg.rf.0256336d7e7d945db5ddf335f3097b71.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/10_mp4-37_jpg.rf.dd8108fe58b63d6e952658e2dec667a1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-11_jpg.rf.eb7a2f3c3bcf58091300f5af498e383e.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-44_jpg.rf.963a709ba0be12904630b0bb1b8d47b0.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-3_jpg.rf.bd6588768c0b73ff537f89246693dda0.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-24_jpg.rf.a3f21fe2d8de6cf32b6e764621a472a9.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-37_jpg.rf.f36158435095f18be51dac0b9082f9c1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/8_mp4-23_jpg.rf.b925a3e8ca3197928e98d4a53af12f0d.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-27_jpg.rf.51ccb25c5a85fe582a56186a9a605ecc.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-20_jpg.rf.629369c91009fb19267aea9b620cf440.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/_annotations.csv
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/6_mp4-21_jpg.rf.6c5b9419e6a48a636766242c33aaa8ae.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/test2_mp4-5_jpg.rf.4a09fadc41431ce8f47ec493e6607738.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/11_mp4-30_jpg.rf.ebc32f17681ef96ef87ad35a7df4f8ce.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-7_jpg.rf.014bc6f8eb5e765634814571e4e0ebd6.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/13_mp4-3_jpg.rf.c4e1d23f8cb1d10f46bd93ba7935b850.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/14_mp4-13_jpg.rf.2b700aacf776452575176f9bcd39be5a.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-23_jpg.rf.b5a2feb8c6c3748bcfeb81e8e5e50044.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/5_mp4-11_jpg.rf.91ad9a7d8c9f22124eedb3614b25d244.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/15_mp4-3_jpg.rf.571ef78f735494ec58a6dc47ca2b24c1.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/2_mp4-2_jpg.rf.21f08e5a11fdf6bc50e4e7eb17f02a4f.txt
# /kaggle/input/traffic-data/traffic_wala_dataset/train/labels/4_mp4-6_jpg.rf.e6aea79b034a43ab502918189dff7d18.txt
# ...
# /kaggle/input/yolo-data/yolo_data/images/test3_mp4-2_jpg.rf.427a25cd37cd34579b0549254b76f8ed.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-15_jpg.rf.203f38a51824a2752509ece8acd0a97b.jpg
# /kaggle/input/yolo-data/yolo_data/images/test2_mp4-10_jpg.rf.560aea78ce9197590eeff18d206a0586.jpg
# /kaggle/input/yolo-data/yolo_data/images/3_mp4-5_jpg.rf.a16d871f4a42e0e4640d12c6222a3efe.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-33_jpg.rf.f43198a40d00d999acb21250bb837256.jpg
# /kaggle/input/yolo-data/yolo_data/images/3_mp4-7_jpg.rf.a244ca9fac9c14239bd81b11985de853.jpg
# /kaggle/input/yolo-data/yolo_data/images/13_mp4-19_jpg.rf.ccad6f714b217391e28055f473cdcfc3.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-4_jpg.rf.9ffe523f7e7e8e84bade81014fb428f3.jpg
# /kaggle/input/yolo-data/yolo_data/images/test_mp4-6_jpg.rf.6980438ce0143b3d0874bf68e4bb00c5.jpg
# /kaggle/input/yolo-data/yolo_data/images/7_mp4-7_jpg.rf.56e4e81d0c272cf24f32de07ea200ae1.jpg
# /kaggle/input/yolo-data/yolo_data/images/11_mp4-3_jpg.rf.2b5cba201b56df739b95e501427ac5f1.jpg
# /kaggle/input/yolo-data/yolo_data/images/7_mp4-15_jpg.rf.81f129cc66a954087df13ff7468586b6.jpg
# /kaggle/input/yolo-data/yolo_data/images/11_mp4-30_jpg.rf.c72fb653509c4234b67115d6eeb6d282.jpg
# /kaggle/input/yolo-data/yolo_data/images/4_mp4-4_jpg.rf.23304bc14339e455081aba910b4167b9.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-47_jpg.rf.e9259514eb111f8a8a33db5bea461edd.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-41_jpg.rf.c935e1a4400371fbed4509e8a77e565a.jpg
# /kaggle/input/yolo-data/yolo_data/images/12_mp4-21_jpg.rf.1a76dc7688ec7362fcda9771f6607ebe.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-15_jpg.rf.54247e977cdc30cf8b27ca8fb7b87871.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-4_jpg.rf.939a7fd223a96cfe6ea6ce6b09be5767.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-5_jpg.rf.c4d1431c00ae66465f5f43a3d1df4d8a.jpg
# /kaggle/input/yolo-data/yolo_data/images/16_mp4-0_jpg.rf.fff3fd2cdb4558d95c9737836ec78767.jpg
# /kaggle/input/yolo-data/yolo_data/images/test_mp4-4_jpg.rf.c92ba4917bf77f870bd07eeac79fdfb1.jpg
# /kaggle/input/yolo-data/yolo_data/images/11_mp4-16_jpg.rf.a1b638ad4d949a9960b7a67a2c8e3316.jpg
# /kaggle/input/yolo-data/yolo_data/images/test_mp4-3_jpg.rf.3e652b310a9473c4d6dcd132699b992c.jpg
# /kaggle/input/yolo-data/yolo_data/images/test_mp4-7_jpg.rf.cf8fd6a7fc83868e8fcc8aa128eff9da.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-22_jpg.rf.864085c1afac497201c5163fee862d09.jpg
# /kaggle/input/yolo-data/yolo_data/images/test3_mp4-16_jpg.rf.545af2db76904c26b74606db905d934b.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-4_jpg.rf.8f2767c92032b487e0abaaaa4dd1c986.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-21_jpg.rf.614ac99808b2a87fe494591f6597ccf1.jpg
# /kaggle/input/yolo-data/yolo_data/images/12_mp4-28_jpg.rf.2eda7e5c85703d24599231e1ee9de874.jpg
# /kaggle/input/yolo-data/yolo_data/images/test2_mp4-0_jpg.rf.18f380b2c42c9868eb11dea014818ee2.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-19_jpg.rf.55b753da9e84a61ecdb1322c020e746f.jpg
# /kaggle/input/yolo-data/yolo_data/images/test2_mp4-15_jpg.rf.908f4888d0fa2c7bde31ba6d17768cf8.jpg
# /kaggle/input/yolo-data/yolo_data/images/12_mp4-1_jpg.rf.0244caebff9c38f077c73832a1b99def.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-34_jpg.rf.5628b69630116859633feaa1b4062547.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-29_jpg.rf.11ac820cd8ab2ff5beac952edd73282b.jpg
# /kaggle/input/yolo-data/yolo_data/images/7_mp4-3_jpg.rf.014252f661a11036b7b07f7dc46b4af8.jpg
# /kaggle/input/yolo-data/yolo_data/images/test3_mp4-1_jpg.rf.016315de09e8befd7cb08f04805bbe98.jpg
# /kaggle/input/yolo-data/yolo_data/images/11_mp4-16_jpg.rf.574de6263b4b33aa750d85b243d4671c.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-26_jpg.rf.eded278a2f01b39511564084ee73fa19.jpg
# /kaggle/input/yolo-data/yolo_data/images/7_mp4-21_jpg.rf.d9c3d2e856caf2596bb5e7885a25ca1e.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-6_jpg.rf.5baaaf56d93028a9c01bc7f1696d033e.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-36_jpg.rf.af56a8b6ab65b8c0beb12417d94fbdf0.jpg
# /kaggle/input/yolo-data/yolo_data/images/13_mp4-14_jpg.rf.4408357b7b363f4bc01fa27757a03c30.jpg
# /kaggle/input/yolo-data/yolo_data/images/12_mp4-20_jpg.rf.f49080daab734a25af85d858615f1d1e.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-23_jpg.rf.35d4eeb8b2fb62d88ceb22132b20a837.jpg
# /kaggle/input/yolo-data/yolo_data/images/11_mp4-5_jpg.rf.c386c42521081b541dc1d2de420dbd6c.jpg
# /kaggle/input/yolo-data/yolo_data/images/2_mp4-11_jpg.rf.730138939319fc38b0f80ebc71dfee4b.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-44_jpg.rf.963a709ba0be12904630b0bb1b8d47b0.jpg
# /kaggle/input/yolo-data/yolo_data/images/5_mp4-2_jpg.rf.80ba24bc2c575533fd8859a640c4e6b7.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-11_jpg.rf.daf2e6df3b3bc1aae86610a58bf141ba.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-5_jpg.rf.01fa21980affb5eef495aeda9ea74e92.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-11_jpg.rf.eb7a2f3c3bcf58091300f5af498e383e.jpg
# /kaggle/input/yolo-data/yolo_data/images/11_mp4-10_jpg.rf.ba5d481d1186cbc496fd795a04c802ae.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-5_jpg.rf.ba3f856015d56022ad3a0d584216405e.jpg
# /kaggle/input/yolo-data/yolo_data/images/13_mp4-11_jpg.rf.c8a8aaf68131d29c1f69f862a45b61e8.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-10_jpg.rf.9f85be68196c57cdc3e5caac4090ca8c.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-18_jpg.rf.de728b4158742cd5145f798bb8f28f1f.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-18_jpg.rf.540554c884e2af926805783564ef50f0.jpg
# /kaggle/input/yolo-data/yolo_data/images/12_mp4-21_jpg.rf.9d2986bb8a605563c3006bae400e21ff.jpg
# /kaggle/input/yolo-data/yolo_data/images/12_mp4-11_jpg.rf.d84d5d40e48a2cd2bb12b38cff026fea.jpg
# /kaggle/input/yolo-data/yolo_data/images/5_mp4-16_jpg.rf.35a8d10e978328cd1ab87e911169b0f9.jpg
# /kaggle/input/yolo-data/yolo_data/images/12_mp4-29_jpg.rf.742ce641675667f01b16cfb310113c24.jpg
# /kaggle/input/yolo-data/yolo_data/images/test2_mp4-5_jpg.rf.4a09fadc41431ce8f47ec493e6607738.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-11_jpg.rf.6e5c9bd73c7d36a6fb8e1a85d0c2edac.jpg
# /kaggle/input/yolo-data/yolo_data/images/5_mp4-18_jpg.rf.a100a7aa041746e8df5dbfa2898a2e57.jpg
# /kaggle/input/yolo-data/yolo_data/images/15_mp4-4_jpg.rf.42ed2a92f886524020cf13233fab7d2b.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-28_jpg.rf.9a9bcb32780aa931718551884825de05.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-17_jpg.rf.d95b42ea41270dad58df2fac3234fc4a.jpg
# /kaggle/input/yolo-data/yolo_data/images/3_mp4-23_jpg.rf.a5486e0d16b0c67ab2cd103acfe81673.jpg
# /kaggle/input/yolo-data/yolo_data/images/15_mp4-4_jpg.rf.798599fc657377631280430897f2b095.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-17_jpg.rf.02e3d8a618f9ac724fa0c2f286c728b2.jpg
# /kaggle/input/yolo-data/yolo_data/images/5_mp4-12_jpg.rf.d85a9310d34099edbdeea033ad180682.jpg
# /kaggle/input/yolo-data/yolo_data/images/11_mp4-21_jpg.rf.de5170ee7fb8d7db8b639de3f87e6bb7.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-26_jpg.rf.4a510cf9628a48a134aba5889a56a228.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-22_jpg.rf.f7ac0d15e2d881abcfac5db4bcd85b93.jpg
# /kaggle/input/yolo-data/yolo_data/images/2_mp4-16_jpg.rf.4b04bbdd5fae04f213e3c91e9c4b1b7d.jpg
# /kaggle/input/yolo-data/yolo_data/images/3_mp4-18_jpg.rf.1a05f45fb34b0e4c4892bcdb677e0a07.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-20_jpg.rf.fddf8750c1c1eaa6e43377e6e5028576.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-38_jpg.rf.2ae3646242c4de70a9aae9f4ac23ef4a.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-26_jpg.rf.feda78d82b8fd572031f985d42e89285.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-20_jpg.rf.26e5de0273080c4d9ce394feed68f5c3.jpg
# /kaggle/input/yolo-data/yolo_data/images/3_mp4-7_jpg.rf.6a4f5863e2cbb994ec424cf728a19a6d.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-48_jpg.rf.b136b51c70d8645bcb71e77a647c9c23.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-16_jpg.rf.96743b16582cfefbb336e23cfc0ad137.jpg
# /kaggle/input/yolo-data/yolo_data/images/3_mp4-18_jpg.rf.28d1e7d7f63dc0f798602069d69e540a.jpg
# /kaggle/input/yolo-data/yolo_data/images/4_mp4-3_jpg.rf.24133af9a76ae8e25d2271059cd57edd.jpg
# /kaggle/input/yolo-data/yolo_data/images/2_mp4-12_jpg.rf.9e1176035b38e59879d9744521174cc9.jpg
# /kaggle/input/yolo-data/yolo_data/images/12_mp4-5_jpg.rf.6f4501c66d7db589329e2b0640a38263.jpg
# /kaggle/input/yolo-data/yolo_data/images/2_mp4-9_jpg.rf.a577fbe347e44a73a27f71bef2280343.jpg
# /kaggle/input/yolo-data/yolo_data/images/12_mp4-17_jpg.rf.6a153289ca1f5817e71ca17f37e1c8e3.jpg
# /kaggle/input/yolo-data/yolo_data/images/3_mp4-3_jpg.rf.2b61a5c3545c950fd089695695854054.jpg
# /kaggle/input/yolo-data/yolo_data/images/3_mp4-0_jpg.rf.486762d73755e270c07dd8cfbeb78c05.jpg
# /kaggle/input/yolo-data/yolo_data/images/12_mp4-19_jpg.rf.724f36e12cf0d5c0de056306b2d256d3.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-3_jpg.rf.effcef40b551938436308ac1eef276bc.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-16_jpg.rf.b6aa0a4716ba080dde464b36bb97c65c.jpg
# /kaggle/input/yolo-data/yolo_data/images/test2_mp4-20_jpg.rf.5f56c19d629aec9af8972f03b80764b4.jpg
# /kaggle/input/yolo-data/yolo_data/images/2_mp4-7_jpg.rf.3631fb077f4c0843c63578b08a8c5260.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-40_jpg.rf.d16cc80521ce7580afbf20eda5adf6d3.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-19_jpg.rf.10897316d2e82a9221d952e5b6da6974.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-10_jpg.rf.ba480b311472ef957256801c3766128a.jpg
# /kaggle/input/yolo-data/yolo_data/images/1_mp4-8_jpg.rf.2641280818f70f41aff18978dc2b189e.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-13_jpg.rf.e8d40904585a9f6d53003e5ef8dbaaf1.jpg
# /kaggle/input/yolo-data/yolo_data/images/15_mp4-1_jpg.rf.4462bddda8bb6bd7cef780afdbd42a90.jpg
# /kaggle/input/yolo-data/yolo_data/images/2_mp4-0_jpg.rf.d84cf4982d8ec443445f3447ed2a8564.jpg
# /kaggle/input/yolo-data/yolo_data/images/12_mp4-9_jpg.rf.6ef67b89a1db64a28d72b3fc76166f18.jpg
# /kaggle/input/yolo-data/yolo_data/images/5_mp4-14_jpg.rf.28be876c6996527d359df0fe43306fc5.jpg
# /kaggle/input/yolo-data/yolo_data/images/4_mp4-10_jpg.rf.fba9a7a37f2fe9391b5ec792264618d7.jpg
# /kaggle/input/yolo-data/yolo_data/images/13_mp4-17_jpg.rf.603c58983348a69f340496081c7c175d.jpg
# /kaggle/input/yolo-data/yolo_data/images/12_mp4-8_jpg.rf.239f33195af4df09618f08d958997ef1.jpg
# /kaggle/input/yolo-data/yolo_data/images/test_mp4-1_jpg.rf.4615955e7a34d3aba2cab0a6139833bf.jpg
# /kaggle/input/yolo-data/yolo_data/images/11_mp4-17_jpg.rf.33e375d128d7ce910854936b2175e4c6.jpg
# /kaggle/input/yolo-data/yolo_data/images/1_mp4-3_jpg.rf.f92d5d0c2629b03306c8fa91917f3ebf.jpg
# /kaggle/input/yolo-data/yolo_data/images/15_mp4-11_jpg.rf.d9560da9663dba2cc2e1c6cc0937ddab.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-7_jpg.rf.436beb74d5ff663cd4a3169a6f142812.jpg
# /kaggle/input/yolo-data/yolo_data/images/4_mp4-6_jpg.rf.e6aea79b034a43ab502918189dff7d18.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-11_jpg.rf.b7bd3f6daf1e3a43806fc9b03b2ecea5.jpg
# /kaggle/input/yolo-data/yolo_data/images/test2_mp4-17_jpg.rf.87e0a998a8066c932ba7dce5edf06fbb.jpg
# /kaggle/input/yolo-data/yolo_data/images/12_mp4-4_jpg.rf.3e5daf1173313cc2c204b1384d04fee8.jpg
# /kaggle/input/yolo-data/yolo_data/images/7_mp4-3_jpg.rf.6dcd52cc1740426e79a54b65ffb993f8.jpg
# /kaggle/input/yolo-data/yolo_data/images/test2_mp4-2_jpg.rf.22744ebb77d52a99c51ede00dca79dfe.jpg
# /kaggle/input/yolo-data/yolo_data/images/11_mp4-8_jpg.rf.76097ce0ac4ef6c0a569cae4a890a860.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-25_jpg.rf.2a6c6c461210b5066240288447ce7606.jpg
# /kaggle/input/yolo-data/yolo_data/images/11_mp4-13_jpg.rf.38f130f1b50209662a12ccffdb286cfd.jpg
# /kaggle/input/yolo-data/yolo_data/images/test_mp4-12_jpg.rf.b981a3feb29e09143cd2674237f43d68.jpg
# /kaggle/input/yolo-data/yolo_data/images/test3_mp4-3_jpg.rf.91ab3bd359dbc8cfe7331b899161be52.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-1_jpg.rf.68dd90fa012e2e4ef45f5031d02ed5cf.jpg
# /kaggle/input/yolo-data/yolo_data/images/15_mp4-1_jpg.rf.d9e25b0686dad85b97ebd560d917fb67.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-31_jpg.rf.e7660e0606787d80a49f7c371a3a9432.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-47_jpg.rf.c9acbc3f5131327b281f3c4efd496455.jpg
# /kaggle/input/yolo-data/yolo_data/images/7_mp4-0_jpg.rf.caff8c9896c6f6985f2dd82b83657e4e.jpg
# /kaggle/input/yolo-data/yolo_data/images/5_mp4-22_jpg.rf.aaa14b7c9dc5def67313b616114423dc.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-43_jpg.rf.ff8ca37b90dd5b5f5fcd2f584a14ea69.jpg
# /kaggle/input/yolo-data/yolo_data/images/2_mp4-6_jpg.rf.f71d57005ef038823826288abf44279f.jpg
# /kaggle/input/yolo-data/yolo_data/images/test_mp4-5_jpg.rf.26235610c8dea9da5c268fdccab4708d.jpg
# /kaggle/input/yolo-data/yolo_data/images/5_mp4-14_jpg.rf.00ee0a5c6158d66128aded7ba6c5e3c2.jpg
# /kaggle/input/yolo-data/yolo_data/images/11_mp4-22_jpg.rf.ad54dce64386ae27a580eaba4148fde4.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-5_jpg.rf.4658c3b313fae76b64c72163de6ffa3a.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-6_jpg.rf.ec7d015efb0295a10936351106b40fd0.jpg
# /kaggle/input/yolo-data/yolo_data/images/15_mp4-14_jpg.rf.b901a8e524e01d09ebfd38f6413c670d.jpg
# /kaggle/input/yolo-data/yolo_data/images/2_mp4-19_jpg.rf.1dad49c01e0d743b9a1836c6d0ee6854.jpg
# /kaggle/input/yolo-data/yolo_data/images/11_mp4-6_jpg.rf.0e2403b7629aac48f36b3f88118526e9.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-24_jpg.rf.17ffb4f2519a46eef09a6ed06a532fa5.jpg
# /kaggle/input/yolo-data/yolo_data/images/5_mp4-17_jpg.rf.2e3ed9c1f0377b9c96f90eca8f4bdb89.jpg
# /kaggle/input/yolo-data/yolo_data/images/13_mp4-4_jpg.rf.ba0414f9ee92cf5450650e6ce58a28b1.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-45_jpg.rf.5aaed7f7db29ad6c15a4b18a7ecc0b7e.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-2_jpg.rf.0256336d7e7d945db5ddf335f3097b71.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-11_jpg.rf.b6939bdda9abe332ee65b4672626d24b.jpg
# /kaggle/input/yolo-data/yolo_data/images/test2_mp4-9_jpg.rf.2b090dabb9ec5f73bf37807b3500b3da.jpg
# /kaggle/input/yolo-data/yolo_data/images/1_mp4-6_jpg.rf.b1942799e938382319ad0a67b09f5737.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-30_jpg.rf.b925fd8ed9bd23c8011292c6eda3e69b.jpg
# /kaggle/input/yolo-data/yolo_data/images/13_mp4-1_jpg.rf.e32506b2b1227a71abf30d5669e62a9a.jpg
# /kaggle/input/yolo-data/yolo_data/images/13_mp4-19_jpg.rf.545677168812e2d50c6902861373205c.jpg
# /kaggle/input/yolo-data/yolo_data/images/7_mp4-14_jpg.rf.f7d5ef7b266e19a8e20bec772d6de106.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-27_jpg.rf.df581ec733941f4a8e951f4c03965299.jpg
# /kaggle/input/yolo-data/yolo_data/images/3_mp4-3_jpg.rf.4cd6ebd1fb8dd1a97e3320f0d63d02bb.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-27_jpg.rf.130965de5fdc30b45137233ee4f810f5.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-36_jpg.rf.4ecae1c1db8d348de07e4f6e9aeff577.jpg
# /kaggle/input/yolo-data/yolo_data/images/7_mp4-4_jpg.rf.86a25e64a8eb7928deb532b33d906cce.jpg
# /kaggle/input/yolo-data/yolo_data/images/test3_mp4-15_jpg.rf.1fac3e2c2d15c1be7beeac54f1257278.jpg
# /kaggle/input/yolo-data/yolo_data/images/3_mp4-5_jpg.rf.a8c17d52a0abb8931cd0f7e3dfaaa42b.jpg
# /kaggle/input/yolo-data/yolo_data/images/10_mp4-11_jpg.rf.eb1b06090bd1c1814b87c18a2661990a.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-2_jpg.rf.8462155edecc784ea2e3184fa218afb7.jpg
# /kaggle/input/yolo-data/yolo_data/images/14_mp4-29_jpg.rf.34ff90a6933dde0cddf6f6a4a92e5c8e.jpg
# /kaggle/input/yolo-data/yolo_data/images/15_mp4-3_jpg.rf.571ef78f735494ec58a6dc47ca2b24c1.jpg
# /kaggle/input/yolo-data/yolo_data/images/1_mp4-10_jpg.rf.7a30b632f34ed5187117135337e41faa.jpg
# /kaggle/input/yolo-data/yolo_data/images/8_mp4-21_jpg.rf.a7f38083157e21d4172d02da10ec8a42.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-18_jpg.rf.a7d2bb35b6d0131ff01083f64244f27c.jpg
# /kaggle/input/yolo-data/yolo_data/images/6_mp4-34_jpg.rf.aa50d3efc81bf097dea5f5253c154aaf.jpg

# %%
import os
import torch
import torch.nn as nn
import torchvision.transforms as T
from torch.utils.data import Dataset, DataLoader
from torchvision.ops import box_iou, nms, sigmoid_focal_loss
from torchvision.utils import draw_bounding_boxes
from PIL import Image, ImageDraw, ImageFont
import albumentations as A
from albumentations.pytorch import ToTensorV2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import torchvision
import math

# --- Paths 
TRAIN_IMG_DIR = "/kaggle/input/traffic-data/traffic_wala_dataset/train/images"
TRAIN_LABEL_DIR = "/kaggle/input/traffic-data/traffic_wala_dataset/train/labels"
VAL_IMG_DIR = "/kaggle/input/traffic-data/traffic_wala_dataset/valid/images"
VAL_LABEL_DIR = "/kaggle/input/traffic-data/traffic_wala_dataset/valid/labels"
TEST_IMG_DIR = "/kaggle/input/traffic-data/traffic_wala_dataset/valid/images"

# --- Utils 
def load_annotations(label_path, original_size):
    boxes = []
    classes = []
    if not os.path.exists(label_path):
        return boxes, classes
    
    orig_w, orig_h = original_size
    with open(label_path, 'r') as f:
        for line in f.readlines():
            cls, cx, cy, w, h = map(float, line.strip().split())
            
            x_center = cx * orig_w
            y_center = cy * orig_h
            box_w = w * orig_w
            box_h = h * orig_h
            
            x_min = x_center - box_w / 2
            y_min = y_center - box_h / 2
            x_max = x_center + box_w / 2
            y_max = y_center + box_h / 2
            
            boxes.append([x_min, y_min, x_max, y_max])
            classes.append(int(cls)) 
    return boxes, classes

# --- Anchor Box Generation 
class AnchorGenerator(nn.Module):
    def __init__(self, input_size, strides, scales, aspect_ratios):
        super().__init__()
        self.input_size = input_size
        self.strides = strides 
        self.scales = scales 
        self.aspect_ratios = aspect_ratios 

        self._all_anchors = self._generate_anchors() 

    def _generate_anchors(self):
        all_anchors = []
        input_h, input_w = self.input_size

        for stride in self.strides:
            feature_h = math.ceil(input_h / stride)
            feature_w = math.ceil(input_w / stride)

            for y in range(feature_h):
                for x in range(feature_w):
                    center_x = (x + 0.5) * stride
                    center_y = (y + 0.5) * stride

                    for base_scale in self.scales:
                        for ratio in self.aspect_ratios:
                            anchor_w = base_scale * math.sqrt(ratio)
                            anchor_h = base_scale / math.sqrt(ratio)

                            xmin = center_x - anchor_w / 2
                            ymin = center_y - anchor_h / 2
                            xmax = center_x + anchor_w / 2
                            ymax = center_y + anchor_h / 2
                            all_anchors.append([xmin, ymin, xmax, ymax])
        
        return torch.tensor(all_anchors, dtype=torch.float32)

    def forward(self):
        return self._all_anchors

# --- Target Assignment 
def assign_targets_to_anchors(anchors, gt_boxes, gt_labels, iou_thresholds=(0.5, 0.4)):
    num_anchors = anchors.shape[0]
    num_gt = gt_boxes.shape[0]

    assigned_labels = torch.full((num_anchors,), -1, dtype=torch.long, device=anchors.device)
    assigned_loc_targets = torch.zeros((num_anchors, 4), dtype=torch.float32, device=anchors.device)
    assigned_gt_boxes_for_pos_anchors = torch.empty((0, 4), dtype=torch.float32, device=anchors.device) 

    if num_gt == 0: 
        assigned_labels[:] = 0 
        return assigned_labels, assigned_loc_targets, assigned_gt_boxes_for_pos_anchors

    iou_matrix = box_iou(anchors, gt_boxes)

    max_iou_per_anchor, best_gt_idx_per_anchor = iou_matrix.max(dim=1) 
    max_iou_per_gt, best_anchor_idx_per_gt = iou_matrix.max(dim=0)     

    assigned_labels[best_anchor_idx_per_gt] = gt_labels[range(num_gt)] 

    positive_mask_iou = max_iou_per_anchor >= iou_thresholds[0]
    assigned_labels[positive_mask_iou] = gt_labels[best_gt_idx_per_anchor[positive_mask_iou]]

    negative_mask_iou = max_iou_per_anchor < iou_thresholds[1]
    already_positive_mask = (assigned_labels == 1)
    assigned_labels[negative_mask_iou & ~already_positive_mask] = 0 

    positive_anchor_indices = torch.where(assigned_labels == 1)[0] 
    if positive_anchor_indices.numel() > 0:
        pos_anchors = anchors[positive_anchor_indices]
        
        assigned_gt_boxes_for_pos_anchors = gt_boxes[best_gt_idx_per_anchor[positive_anchor_indices]]

        pos_anchor_widths = pos_anchors[:, 2] - pos_anchors[:, 0]
        pos_anchor_heights = pos_anchors[:, 3] - pos_anchors[:, 1]
        pos_anchor_center_x = (pos_anchors[:, 0] + pos_anchors[:, 2]) / 2
        pos_anchor_center_y = (pos_anchors[:, 1] + pos_anchors[:, 3]) / 2

        pos_gt_widths = assigned_gt_boxes_for_pos_anchors[:, 2] - assigned_gt_boxes_for_pos_anchors[:, 0]
        pos_gt_heights = assigned_gt_boxes_for_pos_anchors[:, 3] - assigned_gt_boxes_for_pos_anchors[:, 1]
        pos_gt_center_x = (assigned_gt_boxes_for_pos_anchors[:, 0] + assigned_gt_boxes_for_pos_anchors[:, 2]) / 2
        pos_gt_center_y = (assigned_gt_boxes_for_pos_anchors[:, 1] + assigned_gt_boxes_for_pos_anchors[:, 3]) / 2

        tx = (pos_gt_center_x - pos_anchor_center_x) / pos_anchor_widths
        ty = (pos_gt_center_y - pos_anchor_center_y) / pos_anchor_heights
        tw = torch.log(pos_gt_widths / pos_anchor_widths)
        th = torch.log(pos_gt_heights / pos_anchor_heights)

        assigned_loc_targets[positive_anchor_indices] = torch.stack([tx, ty, tw, th], dim=1)

    return assigned_labels, assigned_loc_targets, assigned_gt_boxes_for_pos_anchors

# --- Bounding Box Decoding 
def decode_boxes(anchors, reg_offsets):
    anchor_widths = anchors[:, 2] - anchors[:, 0]
    anchor_heights = anchors[:, 3] - anchors[:, 1]
    anchor_center_x = (anchors[:, 0] + anchors[:, 2]) / 2
    anchor_center_y = (anchors[:, 1] + anchors[:, 3]) / 2

    pred_center_x = anchor_center_x + reg_offsets[:, 0] * anchor_widths
    pred_center_y = anchor_center_y + reg_offsets[:, 1] * anchor_heights

    pred_w = anchor_widths * torch.exp(torch.clamp(reg_offsets[:, 2], -7.0, 7.0)) 
    pred_h = anchor_heights * torch.exp(torch.clamp(reg_offsets[:, 3], -7.0, 7.0))

    pred_xmin = pred_center_x - pred_w / 2
    pred_ymin = pred_center_y - pred_h / 2
    pred_xmax = pred_center_x + pred_w / 2
    pred_ymax = pred_center_y + pred_h / 2

    return torch.stack([pred_xmin, pred_ymin, pred_xmax, pred_ymax], dim=1)

# --- Loss Functions 
class DIoULoss(nn.Module):
    def forward(self, preds_decoded_boxes, targets_gt_boxes):
        if targets_gt_boxes.numel() == 0 or preds_decoded_boxes.numel() == 0:
            return torch.tensor(0.0, device=preds_decoded_boxes.device)

        if preds_decoded_boxes.shape != targets_gt_boxes.shape:
            print("Warning: Shape mismatch in DIoULoss. Ensure 1-to-1 box matching for regression.")
            return torch.tensor(1.0, device=preds_decoded_boxes.device)

        iou = box_iou(preds_decoded_boxes, targets_gt_boxes)
        iou_val = torch.diag(iou)

        preds_cx = (preds_decoded_boxes[:, 0] + preds_decoded_boxes[:, 2]) / 2
        preds_cy = (preds_decoded_boxes[:, 1] + preds_decoded_boxes[:, 3]) / 2
        targets_cx = (targets_gt_boxes[:, 0] + targets_gt_boxes[:, 2]) / 2
        targets_cy = (targets_gt_boxes[:, 1] + targets_gt_boxes[:, 3]) / 2

        center_dist_sq = (preds_cx - targets_cx)**2 + (preds_cy - targets_cy)**2

        enclose_xmin = torch.min(preds_decoded_boxes[:, 0], targets_gt_boxes[:, 0])
        enclose_ymin = torch.min(preds_decoded_boxes[:, 1], targets_gt_boxes[:, 1])
        enclose_xmax = torch.max(preds_decoded_boxes[:, 2], targets_gt_boxes[:, 2])
        enclose_ymax = torch.max(preds_decoded_boxes[:, 3], targets_gt_boxes[:, 3])
        
        enclose_width = enclose_xmax - enclose_xmin
        enclose_height = enclose_ymax - enclose_ymin
        
        c_diag_sq = enclose_width**2 + enclose_height**2

        diou_term = center_dist_sq / (c_diag_sq + 1e-6)
        
        diou_loss = 1 - iou_val + diou_term
        return diou_loss.mean()

# --- Model 
class SimpleRetinaNet(nn.Module):
    def __init__(self, num_classes=1, input_size=(640, 640)):
        super().__init__()
        backbone = torchvision.models.resnet18(pretrained=True)
        self.backbone = nn.Sequential(*list(backbone.children())[:-2]) 
        
        self.input_size = input_size
        
        self.neck = nn.Conv2d(512, 256, kernel_size=1)

        self.strides = [32] 
        self.scales = [32 * 2**0, 32 * 2**(1/3), 32 * 2**(2/3)] 
        self.aspect_ratios = [0.5, 1.0, 2.0] 

        self.num_anchors_per_location = len(self.scales) * len(self.aspect_ratios)
        self.num_classes = num_classes 

        self.cls_head = nn.Sequential(
            nn.Conv2d(256, 256, 3, padding=1),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Conv2d(256, self.num_anchors_per_location * self.num_classes, 1) 
        )
        self.reg_head = nn.Sequential(
            nn.Conv2d(256, 256, 3, padding=1),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Conv2d(256, self.num_anchors_per_location * 4, 1) 
        )
        
        prior_prob = 0.01
        bias_value = -math.log((1 - prior_prob) / prior_prob)
        torch.nn.init.constant_(self.cls_head[-1].bias, bias_value)
        torch.nn.init.normal_(self.cls_head[-1].weight, mean=0, std=0.01)
        
        torch.nn.init.normal_(self.reg_head[-1].weight, mean=0, std=0.01)
        torch.nn.init.constant_(self.reg_head[-1].bias, 0)

        self.anchor_generator = AnchorGenerator(
            input_size=self.input_size, 
            strides=self.strides, 
            scales=self.scales, 
            aspect_ratios=self.aspect_ratios
        )

    def forward(self, x):
        features = self.backbone(x) 
        neck_features = self.neck(features)   

        B, C, H, W = neck_features.shape

        cls_logits = self.cls_head(neck_features) 
        reg_preds = self.reg_head(neck_features)   

        cls_logits = cls_logits.permute(0, 2, 3, 1).contiguous().view(B, -1, self.num_classes)
        reg_preds = reg_preds.permute(0, 2, 3, 1).contiguous().view(B, -1, 4)
        
        return cls_logits, reg_preds

# --- Dataset 
class TrafficDataset(Dataset):
    def __init__(self, img_dir, label_dir, transforms):
        self.img_dir = img_dir
        self.label_dir = label_dir
        self.transforms = transforms
        self.image_files = sorted([f for f in os.listdir(img_dir) if f.endswith('.jpg')])

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.image_files[idx])
        label_path = os.path.join(self.label_dir, os.path.splitext(self.image_files[idx])[0] + '.txt')

        img = Image.open(img_path).convert("RGB")
        original_w, original_h = img.size

        image_np = np.array(img)
        
        if image_np.dtype == np.uint8:
            image_np = image_np.astype(np.float32) / 255.0
        else:
            image_np = image_np.astype(np.float32)

        boxes_original_coords, class_ids = load_annotations(label_path, original_size=(original_w, original_h))
        
        transformed = self.transforms(image=image_np, bboxes=boxes_original_coords)
        image_tensor = transformed["image"]
        boxes_tensor = torch.tensor(transformed["bboxes"], dtype=torch.float32)
        
        gt_class_labels = torch.ones(len(boxes_tensor), dtype=torch.long) if len(boxes_tensor) > 0 else torch.empty(0, dtype=torch.long)

        return image_tensor, (boxes_tensor, gt_class_labels) 

# --- Transforms 
train_tfms = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=0.5),
    A.Resize(640, 640),
    ToTensorV2()
], bbox_params=A.BboxParams(format='pascal_voc', label_fields=[]))

val_tfms = A.Compose([
    A.Resize(640, 640),
    ToTensorV2()
], bbox_params=A.BboxParams(format='pascal_voc', label_fields=[]))

test_tfms = A.Compose([
    A.Resize(640, 640),
    ToTensorV2()
])

# --- Loaders 
def collate_fn_detection(batch):
    images = [item[0] for item in batch]
    gt_info = [item[1] for item in batch] 

    images = torch.stack(images, 0)
    return images, gt_info

train_ds = TrafficDataset(TRAIN_IMG_DIR, TRAIN_LABEL_DIR, train_tfms)
val_ds = TrafficDataset(VAL_IMG_DIR, VAL_LABEL_DIR, val_tfms)

train_loader = DataLoader(train_ds, batch_size=4, shuffle=True, collate_fn=collate_fn_detection)
val_loader = DataLoader(val_ds, batch_size=4, shuffle=False, collate_fn=collate_fn_detection)

# --- Model Setup 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleRetinaNet(num_classes=1, input_size=(640, 640)).to(device)

model.anchors = model.anchor_generator().to(device)

for param in model.backbone.parameters():
    param.requires_grad = False

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.5,
    patience=3,
    verbose=True
)

reg_criterion = DIoULoss() 

# --- Training Loop (Unchanged) 
print("Starting Training...")
for epoch in range(20):
    model.train()
    
    if epoch == 7:
        print("Unfreezing backbone parameters.")
        for param in model.backbone.parameters():
            param.requires_grad = True

    total_cls_loss, total_reg_loss = 0.0, 0.0 
    num_batches = 0

    for images, targets_batch_info in tqdm(train_loader, desc=f"Epoch {epoch+1}"):
        images = images.to(device)
        
        cls_preds_batch, reg_preds_batch = model(images) 

        batch_cls_loss_tensor = torch.tensor(0.0, device=device)
        batch_reg_loss_tensor = torch.tensor(0.0, device=device)
        
        num_valid_samples_for_cls_loss_in_batch = 0 
        num_valid_samples_for_reg_loss_in_batch = 0 

        for i in range(images.shape[0]): 
            gt_boxes_i, gt_labels_i = targets_batch_info[i] 
            gt_boxes_i = gt_boxes_i.to(device)
            gt_labels_i = gt_labels_i.to(device) 

            assigned_labels_i, _, assigned_gt_boxes_for_pos_anchors_i = assign_targets_to_anchors(
                model.anchors, gt_boxes_i, gt_labels_i
            )
            
            cls_logits_i = cls_preds_batch[i, :, 0] 
            
            positive_mask_cls = (assigned_labels_i == 1)
            negative_mask_cls = (assigned_labels_i == 0)
            
            selected_cls_preds = cls_logits_i[positive_mask_cls | negative_mask_cls]
            selected_gt_labels = assigned_labels_i[positive_mask_cls | negative_mask_cls].float()

            if selected_cls_preds.numel() > 0:
                current_cls_loss_img = sigmoid_focal_loss(selected_cls_preds, selected_gt_labels, 
                                                     reduction='sum', alpha=0.25, gamma=2.0)
                batch_cls_loss_tensor += current_cls_loss_img
                num_valid_samples_for_cls_loss_in_batch += 1

            positive_anchor_indices = torch.where(assigned_labels_i == 1)[0]

            if positive_anchor_indices.numel() > 0:
                reg_preds_pos = reg_preds_batch[i, positive_anchor_indices] 
                
                decoded_pred_boxes = decode_boxes(model.anchors[positive_anchor_indices], reg_preds_pos)
                
                gt_boxes_pos = assigned_gt_boxes_for_pos_anchors_i 

                current_reg_loss_img = reg_criterion(decoded_pred_boxes, gt_boxes_pos)
                batch_reg_loss_tensor += current_reg_loss_img 
                num_valid_samples_for_reg_loss_in_batch += 1 

        if num_valid_samples_for_cls_loss_in_batch > 0:
            batch_cls_loss_tensor /= num_valid_samples_for_cls_loss_in_batch
        else:
            batch_cls_loss_tensor = torch.tensor(0.0, device=device) 

        if num_valid_samples_for_reg_loss_in_batch > 0:
            batch_reg_loss_tensor /= num_valid_samples_for_reg_loss_in_batch
        else:
            batch_reg_loss_tensor = torch.tensor(0.0, device=device) 
            
        loss = batch_cls_loss_tensor + batch_reg_loss_tensor
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_cls_loss += batch_cls_loss_tensor.item()
        total_reg_loss += batch_reg_loss_tensor.item()
        num_batches += 1

    print(f"[Epoch {epoch+1}] Avg cls_loss: {total_cls_loss / num_batches:.4f}, Avg reg_loss: {total_reg_loss / num_batches:.4f}")

print("\nTraining Complete!")

# --- Inference on Test Images ---
print("\n--- Starting Inference on Test Images ---")

model.eval()

# --- Define output directories for saving images and labels ---
OUTPUT_BASE_DIR = "./inference_outputs"
OUTPUT_IMG_DIR = os.path.join(OUTPUT_BASE_DIR, "images_with_detections")
OUTPUT_LABEL_DIR = os.path.join(OUTPUT_BASE_DIR, "labels_yolo_format")
OUTPUT_TXT_FILE = os.path.join(OUTPUT_BASE_DIR, "output.txt")

os.makedirs(OUTPUT_IMG_DIR, exist_ok=True)
os.makedirs(OUTPUT_LABEL_DIR, exist_ok=True)
print(f"Detected images will be saved to: {OUTPUT_IMG_DIR}")
print(f"Detection labels (YOLO format) will be saved to: {OUTPUT_LABEL_DIR}")
print(f"Inference summary will be saved to: {OUTPUT_TXT_FILE}")

# Open the output.txt file in write mode
with open(OUTPUT_TXT_FILE, 'w') as output_txt:
    test_image_files = sorted([f for f in os.listdir(TEST_IMG_DIR) if f.endswith('.jpg')])

    if not test_image_files:
        print(f"No JPG images found in {TEST_IMG_DIR}. Skipping inference.")
    else:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        model.to(device)

        for img_file in tqdm(test_image_files, desc="Running Inference"):
            img_path = os.path.join(TEST_IMG_DIR, img_file)

            pil_image = Image.open(img_path).convert("RGB")
            original_width, original_height = pil_image.size

            image_np_for_inference = np.array(pil_image)
            if image_np_for_inference.dtype == np.uint8:
                image_np_for_inference = image_np_for_inference.astype(np.float32) / 255.0
            elif np.max(image_np_for_inference) > 1.0:
                image_np_for_inference = image_np_for_inference / 255.0

            transformed = test_tfms(image=image_np_for_inference)
            image_tensor = transformed["image"].unsqueeze(0).to(device)

            with torch.no_grad():
                cls_logits, reg_preds = model(image_tensor)

                cls_logits = cls_logits.squeeze(0)
                reg_preds = reg_preds.squeeze(0)

                pred_scores = cls_logits.sigmoid()[:, 0]
                decoded_boxes = decode_boxes(model.anchors, reg_preds)

                score_threshold = 0.5
                keep = pred_scores >= score_threshold
                
                final_boxes = decoded_boxes[keep]
                final_scores = pred_scores[keep]

                if final_boxes.numel() > 0:
                    nms_threshold = 0.4
                    keep_indices = nms(final_boxes, final_scores, nms_threshold)
                    final_boxes = final_boxes[keep_indices]
                    final_scores = final_scores[keep_indices]
                else:
                    final_boxes = torch.empty((0, 4), device=device)
                    final_scores = torch.empty(0, device=device)

                # --- Prepare for saving ---
                output_image_filename = img_file
                output_label_filename = os.path.splitext(img_file)[0] + '.txt'
                output_image_path = os.path.join(OUTPUT_IMG_DIR, output_image_filename)
                output_label_path = os.path.join(OUTPUT_LABEL_DIR, output_label_filename)

                yolo_labels = []

                if final_boxes.numel() > 0:
                    scale_x = original_width / 640.0
                    scale_y = original_height / 640.0
                    
                    final_boxes_orig_coords = final_boxes.clone()
                    final_boxes_orig_coords[:, 0] *= scale_x
                    final_boxes_orig_coords[:, 1] *= scale_y
                    final_boxes_orig_coords[:, 2] *= scale_x
                    final_boxes_orig_coords[:, 3] *= scale_y

                    draw = ImageDraw.Draw(pil_image)
                    try:
                        font = ImageFont.truetype("arial.ttf", 20)
                    except IOError:
                        font = ImageFont.load_default()

                    for i in range(len(final_boxes_orig_coords)):
                        box = final_boxes_orig_coords[i].cpu().numpy()
                        score = final_scores[i].item()
                        label_class_id = 0

                        box_int = box.astype(int)
                        draw.rectangle([(box_int[0], box_int[1]), (box_int[2], box_int[3])], outline="red", width=2)
                        
                        text = f"Object: {score:.2f}"
                        try:
                            text_width, text_height = draw.textsize(text, font=font)
                        except AttributeError:
                            text_width = len(text) * 10
                            text_height = 20
                        
                        text_position = (box_int[0], box_int[1] - text_height - 2 if box_int[1] - text_height - 2 > 0 else box_int[1] + 2)
                        draw.rectangle([text_position, (text_position[0] + text_width, text_position[1] + text_height)], fill="red")
                        draw.text(text_position, text, fill="white", font=font)

                        x_min, y_min, x_max, y_max = box[0], box[1], box[2], box[3]
                        
                        box_width = x_max - x_min
                        box_height = y_max - y_min
                        x_center = (x_min + x_max) / 2
                        y_center = (y_min + y_max) / 2

                        x_center_norm = x_center / original_width
                        y_center_norm = y_center / original_height
                        width_norm = box_width / original_width
                        height_norm = box_height / original_height

                        yolo_labels.append(f"{label_class_id} {x_center_norm:.6f} {y_center_norm:.6f} {width_norm:.6f} {height_norm:.6f}")
                    
                    # --- Added Lane Counting and Vehicle Density ---
                    vehicle_boxes = final_boxes  # Use the boxes in resized 640x640 space
                    width, height = 640, 640  # Image dimensions after resizing (from test_tfms)

                    left_lane_count = 0
                    right_lane_count = 0

                    for box in vehicle_boxes:
                        x1, _, x2, _ = box
                        box_center_x = (x1 + x2) / 2
                        if box_center_x < width / 2:
                            left_lane_count += 1
                        else:
                            right_lane_count += 1

                    image_area = width * height
                    vehicle_density = len(vehicle_boxes) / image_area

                    # Write to output.txt
                    output_txt.write(f"Image: {img_file}\n")
                    output_txt.write(f"Total Detections: {len(final_boxes)}\n")
                    for label in yolo_labels:
                        output_txt.write(f"{label}\n")
                    output_txt.write(f"Vehicles in Left Lane: {left_lane_count}\n")
                    output_txt.write(f"Vehicles in Right Lane: {right_lane_count}\n")
                    output_txt.write(f"Vehicle Density: {vehicle_density:.6f} vehicles per pixel\n")
                    output_txt.write("-" * 50 + "\n")

                    pil_image.save(output_image_path)
                    with open(output_label_path, 'w') as f:
                        for line in yolo_labels:
                            f.write(line + '\n')

                else:
                    # Write to output.txt for no detections
                    output_txt.write(f"Image: {img_file}\n")
                    output_txt.write("Total Detections: 0\n")
                    output_txt.write("Vehicles in Left Lane: 0\n")
                    output_txt.write("Vehicles in Right Lane: 0\n")
                    output_txt.write("Vehicle Density: 0.000000 vehicles per pixel\n")
                    output_txt.write("-" * 50 + "\n")

                    pil_image.save(output_image_path)
                    with open(output_label_path, 'w') as f:
                        pass

print("\nInference complete. Check the 'inference_outputs' directory for results.")
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Starting Training...
# Epoch 1: 100%|██████████| 134/134 [00:23<00:00,  5.67it/s]
# [Epoch 1] Avg cls_loss: 9.8562, Avg reg_loss: 0.5891
# Epoch 2: 100%|██████████| 134/134 [00:19<00:00,  6.71it/s]
# [Epoch 2] Avg cls_loss: 7.5405, Avg reg_loss: 0.5580
# Epoch 3: 100%|██████████| 134/134 [00:19<00:00,  6.91it/s]
# [Epoch 3] Avg cls_loss: 6.9139, Avg reg_loss: 0.5430
# Epoch 4: 100%|██████████| 134/134 [00:19<00:00,  6.72it/s]
# [Epoch 4] Avg cls_loss: 6.5019, Avg reg_loss: 0.5283
# Epoch 5: 100%|██████████| 134/134 [00:19<00:00,  6.92it/s]
# [Epoch 5] Avg cls_loss: 6.0608, Avg reg_loss: 0.5193
# Epoch 6: 100%|██████████| 134/134 [00:19<00:00,  6.74it/s]
# [Epoch 6] Avg cls_loss: 5.7850, Avg reg_loss: 0.5079
# Epoch 7: 100%|██████████| 134/134 [00:19<00:00,  6.84it/s]
# [Epoch 7] Avg cls_loss: 5.5186, Avg reg_loss: 0.4974
# Unfreezing backbone parameters.
# Epoch 8: 100%|██████████| 134/134 [00:23<00:00,  5.60it/s]
# [Epoch 8] Avg cls_loss: 4.6743, Avg reg_loss: 0.4964
# Epoch 9: 100%|██████████| 134/134 [00:23<00:00,  5.74it/s]
# [Epoch 9] Avg cls_loss: 3.4417, Avg reg_loss: 0.4740
# Epoch 10: 100%|██████████| 134/134 [00:23<00:00,  5.63it/s]
# [Epoch 10] Avg cls_loss: 2.8577, Avg reg_loss: 0.4547
# Epoch 11: 100%|██████████| 134/134 [00:23<00:00,  5.72it/s]
# [Epoch 11] Avg cls_loss: 2.4283, Avg reg_loss: 0.4411
# Epoch 12: 100%|██████████| 134/134 [00:24<00:00,  5.57it/s]
# [Epoch 12] Avg cls_loss: 2.1050, Avg reg_loss: 0.4344
# Epoch 13: 100%|██████████| 134/134 [00:23<00:00,  5.69it/s]
# [Epoch 13] Avg cls_loss: 1.8446, Avg reg_loss: 0.4208
# Epoch 14: 100%|██████████| 134/134 [00:23<00:00,  5.65it/s]
# [Epoch 14] Avg cls_loss: 1.5988, Avg reg_loss: 0.4127
# Epoch 15: 100%|██████████| 134/134 [00:23<00:00,  5.60it/s]
# [Epoch 15] Avg cls_loss: 1.4037, Avg reg_loss: 0.3965
# Epoch 16: 100%|██████████| 134/134 [00:24<00:00,  5.57it/s]
# [Epoch 16] Avg cls_loss: 1.2694, Avg reg_loss: 0.3893
# Epoch 17: 100%|██████████| 134/134 [00:23<00:00,  5.62it/s]
# [Epoch 17] Avg cls_loss: 1.1220, Avg reg_loss: 0.3884
# Epoch 18: 100%|██████████| 134/134 [00:23<00:00,  5.68it/s]
# [Epoch 18] Avg cls_loss: 1.0108, Avg reg_loss: 0.3764
# Epoch 19: 100%|██████████| 134/134 [00:24<00:00,  5.49it/s]
# [Epoch 19] Avg cls_loss: 0.9416, Avg reg_loss: 0.3675
# Epoch 20: 100%|██████████| 134/134 [00:23<00:00,  5.69it/s]
# [Epoch 20] Avg cls_loss: 0.7794, Avg reg_loss: 0.3618
#
# Training Complete!
#
# --- Starting Inference on Test Images ---
# Detected images will be saved to: ./inference_outputs/images_with_detections
# Detection labels (YOLO format) will be saved to: ./inference_outputs/labels_yolo_format
# Inference summary will be saved to: ./inference_outputs/output.txt
# Running Inference: 100%|██████████| 90/90 [00:02<00:00, 33.21it/s]
# Inference complete. Check the 'inference_outputs' directory for results.
